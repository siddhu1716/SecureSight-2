# %%
from ultralytics import YOLO
import cv2

import util
from sort.sort import *
from util import get_car, read_license_plate, write_csv

results = {}

mot_tracker = Sort()
# Out:
# Using CPU. Note: This module is much faster with a GPU.

# %%
results = {}

mot_tracker = Sort()

# %%
# load models
coco_model = YOLO('yolov8n.pt')
license_plate_detector = YOLO('/home/mcw/Desktop/work/anpr/Automatic-License-Plate-Recognition-using-YOLOv8/license_plate_detector.pt')

# load video
cap = cv2.VideoCapture('/home/mcw/Desktop/work/anpr/sample.mp4')

vehicles = [2, 3, 5, 7]
# Out:
# /home/mcw/Desktop/work/anpr/.venv/lib/python3.12/site-packages/ultralytics/nn/tasks.py:511: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(file, map_location='cpu'), file  # load

# %%
# read frames
frame_nmr = -1
ret = True
while ret:
    frame_nmr += 1
    ret, frame = cap.read()
    if ret:
        results[frame_nmr] = {}
        # detect vehicles
        detections = coco_model(frame)[0]
        detections_ = []
        for detection in detections.boxes.data.tolist():
            x1, y1, x2, y2, score, class_id = detection
            if int(class_id) in vehicles:
                detections_.append([x1, y1, x2, y2, score])

        # track vehicles
        track_ids = mot_tracker.update(np.asarray(detections_))

        # detect license plates
        license_plates = license_plate_detector(frame)[0]
        for license_plate in license_plates.boxes.data.tolist():
            x1, y1, x2, y2, score, class_id = license_plate

            # assign license plate to car
            xcar1, ycar1, xcar2, ycar2, car_id = get_car(license_plate, track_ids)

            if car_id != -1:

                # crop license plate
                license_plate_crop = frame[int(y1):int(y2), int(x1): int(x2), :]

                # process license plate
                license_plate_crop_gray = cv2.cvtColor(license_plate_crop, cv2.COLOR_BGR2GRAY)
                _, license_plate_crop_thresh = cv2.threshold(license_plate_crop_gray, 64, 255, cv2.THRESH_BINARY_INV)

                # read license plate number
                license_plate_text, license_plate_text_score = read_license_plate(license_plate_crop_thresh)

                if license_plate_text is not None:
                    results[frame_nmr][car_id] = {'car': {'bbox': [xcar1, ycar1, xcar2, ycar2]},
                                                  'license_plate': {'bbox': [x1, y1, x2, y2],
                                                                    'text': license_plate_text,
                                                                    'bbox_score': score,
                                                                    'text_score': license_plate_text_score}}
# Out:
# 0: 384x640 21 cars, 1 bus, 2 trucks, 81.0ms
# Speed: 2.8ms preprocess, 81.0ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 43.5ms
# Speed: 1.1ms preprocess, 43.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 22 cars, 1 bus, 2 trucks, 43.6ms
# Speed: 0.9ms preprocess, 43.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 29.9ms
# Speed: 0.9ms preprocess, 29.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 27 cars, 1 bus, 2 trucks, 31.0ms
# Speed: 0.7ms preprocess, 31.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 30.1ms
# Speed: 0.8ms preprocess, 30.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 24 cars, 1 bus, 1 truck, 31.8ms
# Speed: 0.9ms preprocess, 31.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 28.9ms
# Speed: 0.8ms preprocess, 28.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 24 cars, 1 bus, 1 truck, 33.3ms
# Speed: 0.7ms preprocess, 33.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 35.1ms
# Speed: 1.3ms preprocess, 35.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 25 cars, 1 bus, 1 truck, 47.0ms
# Speed: 1.0ms preprocess, 47.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 45.0ms
# Speed: 1.0ms preprocess, 45.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 22 cars, 1 bus, 2 trucks, 46.8ms
# Speed: 1.0ms preprocess, 46.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 43.3ms
# Speed: 0.9ms preprocess, 43.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 23 cars, 1 bus, 2 trucks, 45.3ms
# Speed: 0.9ms preprocess, 45.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 44.9ms
# Speed: 0.9ms preprocess, 44.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 22 cars, 1 bus, 2 trucks, 47.7ms
# Speed: 0.9ms preprocess, 47.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 40.7ms
# Speed: 0.9ms preprocess, 40.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 20 cars, 1 bus, 2 trucks, 49.0ms
# Speed: 0.9ms preprocess, 49.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 49.2ms
# Speed: 0.9ms preprocess, 49.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 21 cars, 1 bus, 1 truck, 45.0ms
# Speed: 0.9ms preprocess, 45.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 39.5ms
# Speed: 1.3ms preprocess, 39.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 20 cars, 1 bus, 1 truck, 33.1ms
# Speed: 0.9ms preprocess, 33.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 33.3ms
# Speed: 0.9ms preprocess, 33.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 20 cars, 1 bus, 1 truck, 37.2ms
# Speed: 0.9ms preprocess, 37.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 33.1ms
# Speed: 0.8ms preprocess, 33.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 22 cars, 1 bus, 2 trucks, 48.6ms
# Speed: 1.1ms preprocess, 48.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 45.6ms
# Speed: 1.0ms preprocess, 45.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 21 cars, 1 bus, 1 truck, 47.7ms
# Speed: 1.0ms preprocess, 47.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 43.2ms
# Speed: 1.1ms preprocess, 43.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 21 cars, 1 bus, 1 truck, 45.9ms
# Speed: 1.1ms preprocess, 45.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 31.5ms
# Speed: 0.7ms preprocess, 31.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 21 cars, 1 bus, 1 truck, 32.3ms
# Speed: 0.8ms preprocess, 32.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 36.5ms
# Speed: 0.9ms preprocess, 36.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 20 cars, 1 bus, 1 truck, 36.8ms
# Speed: 1.1ms preprocess, 36.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 35.5ms
# Speed: 0.8ms preprocess, 35.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 19 cars, 2 buss, 1 truck, 52.9ms
# Speed: 0.8ms preprocess, 52.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 30.9ms
# Speed: 1.0ms preprocess, 30.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 19 cars, 2 buss, 1 truck, 41.7ms
# Speed: 1.0ms preprocess, 41.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 39.5ms
# Speed: 0.9ms preprocess, 39.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 17 cars, 1 bus, 1 truck, 45.9ms
# Speed: 0.8ms preprocess, 45.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 42.5ms
# Speed: 0.8ms preprocess, 42.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 16 cars, 2 buss, 1 truck, 30.1ms
# Speed: 1.1ms preprocess, 30.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 28.4ms
# Speed: 0.8ms preprocess, 28.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 18 cars, 1 bus, 1 truck, 45.8ms
# Speed: 1.2ms preprocess, 45.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 44.1ms
# Speed: 0.8ms preprocess, 44.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 19 cars, 1 bus, 1 truck, 45.4ms
# Speed: 0.9ms preprocess, 45.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 43.0ms
# Speed: 0.9ms preprocess, 43.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 17 cars, 1 bus, 1 truck, 31.4ms
# Speed: 0.8ms preprocess, 31.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 43.5ms
# Speed: 0.8ms preprocess, 43.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 19 cars, 2 buss, 1 truck, 44.5ms
# Speed: 0.8ms preprocess, 44.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 42.1ms
# Speed: 0.8ms preprocess, 42.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 17 cars, 1 bus, 1 truck, 45.1ms
# Speed: 0.9ms preprocess, 45.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 42.9ms
# Speed: 0.9ms preprocess, 42.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 19 cars, 2 buss, 1 truck, 46.1ms
# Speed: 1.0ms preprocess, 46.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 42.6ms
# Speed: 0.9ms preprocess, 42.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 18 cars, 2 buss, 1 truck, 44.5ms
# Speed: 0.8ms preprocess, 44.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 30.3ms
# Speed: 0.7ms preprocess, 30.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 19 cars, 1 bus, 1 truck, 45.2ms
# Speed: 0.9ms preprocess, 45.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 42.8ms
# Speed: 0.9ms preprocess, 42.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 17 cars, 1 bus, 45.8ms
# Speed: 0.9ms preprocess, 45.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 36.2ms
# Speed: 0.8ms preprocess, 36.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 17 cars, 1 bus, 30.4ms
# Speed: 1.0ms preprocess, 30.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 28.7ms
# Speed: 0.8ms preprocess, 28.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 21 cars, 1 bus, 1 truck, 33.1ms
# Speed: 0.8ms preprocess, 33.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 45.0ms
# Speed: 0.9ms preprocess, 45.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 21 cars, 1 bus, 2 trucks, 32.3ms
# Speed: 0.9ms preprocess, 32.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 44.6ms
# Speed: 0.9ms preprocess, 44.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 20 cars, 1 bus, 2 trucks, 29.2ms
# Speed: 0.9ms preprocess, 29.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 27.6ms
# Speed: 0.8ms preprocess, 27.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 19 cars, 1 bus, 2 trucks, 40.1ms
# Speed: 1.3ms preprocess, 40.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 30.6ms
# Speed: 0.8ms preprocess, 30.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 19 cars, 1 bus, 1 truck, 34.5ms
# Speed: 1.1ms preprocess, 34.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 44.3ms
# Speed: 0.8ms preprocess, 44.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 20 cars, 1 bus, 1 truck, 33.8ms
# Speed: 0.9ms preprocess, 33.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 29.4ms
# Speed: 0.7ms preprocess, 29.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 21 cars, 1 bus, 1 truck, 32.0ms
# Speed: 0.8ms preprocess, 32.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 39.2ms
# Speed: 1.0ms preprocess, 39.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 21 cars, 1 bus, 1 truck, 30.9ms
# Speed: 0.7ms preprocess, 30.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 28.8ms
# Speed: 1.0ms preprocess, 28.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 20 cars, 1 bus, 1 truck, 30.0ms
# Speed: 0.8ms preprocess, 30.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 42.9ms
# Speed: 0.8ms preprocess, 42.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 19 cars, 1 bus, 1 truck, 45.1ms
# Speed: 0.9ms preprocess, 45.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 42.5ms
# Speed: 0.8ms preprocess, 42.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 18 cars, 1 bus, 1 truck, 44.8ms
# Speed: 1.0ms preprocess, 44.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 43.1ms
# Speed: 0.9ms preprocess, 43.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 16 cars, 1 bus, 1 truck, 36.0ms
# Speed: 0.8ms preprocess, 36.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 28.9ms
# Speed: 0.8ms preprocess, 28.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 18 cars, 1 bus, 1 truck, 44.2ms
# Speed: 1.1ms preprocess, 44.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 29.0ms
# Speed: 0.9ms preprocess, 29.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 16 cars, 1 bus, 1 truck, 44.6ms
# Speed: 1.2ms preprocess, 44.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 41.8ms
# Speed: 0.9ms preprocess, 41.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 18 cars, 1 bus, 1 truck, 30.5ms
# Speed: 0.9ms preprocess, 30.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 40.5ms
# Speed: 1.0ms preprocess, 40.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 18 cars, 1 bus, 2 trucks, 30.2ms
# Speed: 0.7ms preprocess, 30.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 28.7ms
# Speed: 0.8ms preprocess, 28.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 18 cars, 1 bus, 2 trucks, 30.0ms
# Speed: 0.8ms preprocess, 30.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 34.1ms
# Speed: 0.8ms preprocess, 34.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 18 cars, 1 bus, 2 trucks, 38.1ms
# Speed: 1.0ms preprocess, 38.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 29.0ms
# Speed: 0.6ms preprocess, 29.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 20 cars, 1 bus, 3 trucks, 29.2ms
# Speed: 0.8ms preprocess, 29.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 27.8ms
# Speed: 0.7ms preprocess, 27.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 20 cars, 1 bus, 3 trucks, 30.5ms
# Speed: 0.8ms preprocess, 30.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 28.6ms
# Speed: 0.8ms preprocess, 28.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 18 cars, 1 bus, 2 trucks, 38.4ms
# Speed: 1.0ms preprocess, 38.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 27.9ms
# Speed: 0.8ms preprocess, 27.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 20 cars, 1 bus, 2 trucks, 32.3ms
# Speed: 0.8ms preprocess, 32.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 29.2ms
# Speed: 0.8ms preprocess, 29.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 20 cars, 1 bus, 1 truck, 32.5ms
# Speed: 0.8ms preprocess, 32.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 31.2ms
# Speed: 0.9ms preprocess, 31.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 19 cars, 1 bus, 1 truck, 34.0ms
# Speed: 1.0ms preprocess, 34.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 37.9ms
# Speed: 1.0ms preprocess, 37.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 19 cars, 2 buss, 1 truck, 48.0ms
# Speed: 1.1ms preprocess, 48.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 38.5ms
# Speed: 1.0ms preprocess, 38.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 17 cars, 2 buss, 1 truck, 30.8ms
# Speed: 0.8ms preprocess, 30.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 43.9ms
# Speed: 0.8ms preprocess, 43.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 18 cars, 2 buss, 1 truck, 45.6ms
# Speed: 0.9ms preprocess, 45.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 license_plates, 43.1ms
# Speed: 1.1ms preprocess, 43.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 17 cars, 1 bus, 1 truck, 32.0ms
# Speed: 0.9ms preprocess, 32.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 29.8ms
# Speed: 0.8ms preprocess, 29.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 17 cars, 1 bus, 1 truck, 31.3ms
# Speed: 0.8ms preprocess, 31.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 44.6ms
# Speed: 1.2ms preprocess, 44.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 16 cars, 1 bus, 1 truck, 47.6ms
# Speed: 0.9ms preprocess, 47.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 29.7ms
# Speed: 0.9ms preprocess, 29.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 19 cars, 2 buss, 1 truck, 30.7ms
# Speed: 0.7ms preprocess, 30.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 29.8ms
# Speed: 0.8ms preprocess, 29.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 19 cars, 1 bus, 1 truck, 32.8ms
# Speed: 0.9ms preprocess, 32.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 28.8ms
# Speed: 0.7ms preprocess, 28.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 19 cars, 2 buss, 1 truck, 30.7ms
# Speed: 0.8ms preprocess, 30.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 28.7ms
# Speed: 0.7ms preprocess, 28.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 17 cars, 1 bus, 1 truck, 30.9ms
# Speed: 0.8ms preprocess, 30.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 29.0ms
# Speed: 0.9ms preprocess, 29.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 18 cars, 1 bus,
4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 22 cars, 1 bus, 2 trucks, 29.4ms
# Speed: 0.8ms preprocess, 29.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 license_plates, 28.0ms
# Speed: 0.8ms preprocess, 28.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 22 cars, 1 bus, 2 trucks, 28.0ms
# Speed: 0.8ms preprocess, 28.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 26.7ms
# Speed: 0.7ms preprocess, 26.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 22 cars, 1 bus, 2 trucks, 28.1ms
# Speed: 0.8ms preprocess, 28.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 license_plates, 26.7ms
# Speed: 0.8ms preprocess, 26.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 24 cars, 1 bus, 1 truck, 29.9ms
# Speed: 0.8ms preprocess, 29.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 license_plates, 27.1ms
# Speed: 0.7ms preprocess, 27.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 23 cars, 1 bus, 2 trucks, 28.2ms
# Speed: 0.8ms preprocess, 28.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 license_plates, 34.3ms
# Speed: 0.7ms preprocess, 34.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 24 cars, 1 bus, 1 truck, 40.0ms
# Speed: 0.9ms preprocess, 40.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 license_plates, 38.7ms
# Speed: 1.5ms preprocess, 38.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 24 cars, 1 bus, 1 truck, 32.0ms
# Speed: 0.8ms preprocess, 32.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 33.3ms
# Speed: 0.8ms preprocess, 33.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 23 cars, 1 bus, 40.0ms
# Speed: 1.1ms preprocess, 40.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 47.0ms
# Speed: 1.0ms preprocess, 47.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 24 cars, 1 bus, 1 truck, 49.1ms
# Speed: 1.1ms preprocess, 49.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 license_plates, 30.8ms
# Speed: 0.8ms preprocess, 30.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 23 cars, 1 bus, 1 truck, 48.5ms
# Speed: 1.0ms preprocess, 48.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 license_plates, 43.1ms
# Speed: 0.9ms preprocess, 43.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 22 cars, 1 bus, 1 truck, 31.7ms
# Speed: 0.8ms preprocess, 31.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 license_plates, 29.3ms
# Speed: 0.8ms preprocess, 29.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 27 cars, 1 bus, 1 truck, 30.6ms
# Speed: 0.8ms preprocess, 30.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 license_plates, 29.6ms
# Speed: 0.8ms preprocess, 29.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 25 cars, 1 bus, 1 truck, 31.9ms
# Speed: 0.9ms preprocess, 31.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 29.6ms
# Speed: 0.8ms preprocess, 29.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 24 cars, 1 bus, 1 truck, 32.1ms
# Speed: 0.8ms preprocess, 32.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 31.5ms
# Speed: 1.0ms preprocess, 31.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 24 cars, 1 bus, 1 truck, 47.9ms
# Speed: 0.9ms preprocess, 47.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 43.8ms
# Speed: 0.9ms preprocess, 43.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 25 cars, 1 bus, 30.2ms
# Speed: 0.9ms preprocess, 30.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 29.1ms
# Speed: 0.8ms preprocess, 29.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 22 cars, 1 bus, 30.0ms
# Speed: 0.7ms preprocess, 30.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 27.7ms
# Speed: 0.6ms preprocess, 27.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 28 cars, 1 bus, 1 truck, 32.8ms
# Speed: 1.2ms preprocess, 32.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 38.4ms
# Speed: 1.2ms preprocess, 38.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 25 cars, 1 bus, 1 truck, 54.1ms
# Speed: 0.9ms preprocess, 54.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 44.2ms
# Speed: 0.8ms preprocess, 44.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 25 cars, 2 buss, 1 truck, 29.3ms
# Speed: 0.8ms preprocess, 29.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 35.2ms
# Speed: 0.8ms preprocess, 35.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 25 cars, 1 bus, 1 truck, 46.5ms
# Speed: 1.0ms preprocess, 46.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 27.9ms
# Speed: 0.9ms preprocess, 27.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 25 cars, 1 bus, 1 truck, 36.5ms
# Speed: 0.8ms preprocess, 36.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 35.0ms
# Speed: 1.1ms preprocess, 35.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 24 cars, 1 bus, 1 truck, 32.0ms
# Speed: 0.8ms preprocess, 32.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 29.8ms
# Speed: 0.8ms preprocess, 29.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 23 cars, 1 bus, 1 truck, 47.1ms
# Speed: 0.9ms preprocess, 47.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 30.2ms
# Speed: 0.8ms preprocess, 30.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 24 cars, 1 bus, 2 trucks, 29.1ms
# Speed: 0.9ms preprocess, 29.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 34.5ms
# Speed: 0.8ms preprocess, 34.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 25 cars, 1 bus, 2 trucks, 31.8ms
# Speed: 0.8ms preprocess, 31.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 29.6ms
# Speed: 0.8ms preprocess, 29.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 23 cars, 1 bus, 2 trucks, 37.2ms
# Speed: 0.9ms preprocess, 37.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 29.9ms
# Speed: 0.8ms preprocess, 29.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 23 cars, 1 bus, 2 trucks, 33.1ms
# Speed: 0.8ms preprocess, 33.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 47.4ms
# Speed: 0.9ms preprocess, 47.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 24 cars, 1 bus, 2 trucks, 31.9ms
# Speed: 0.7ms preprocess, 31.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 44.3ms
# Speed: 0.9ms preprocess, 44.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 24 cars, 1 bus, 1 truck, 31.1ms
# Speed: 0.9ms preprocess, 31.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 30.3ms
# Speed: 0.8ms preprocess, 30.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 22 cars, 1 bus, 1 truck,
1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 license_plates, 46.8ms
# Speed: 0.9ms preprocess, 46.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 24 cars, 2 trucks, 49.8ms
# Speed: 0.9ms preprocess, 49.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 46.6ms
# Speed: 1.0ms preprocess, 46.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 22 cars, 2 trucks, 36.5ms
# Speed: 0.8ms preprocess, 36.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 33.1ms
# Speed: 0.8ms preprocess, 33.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 23 cars, 2 trucks, 43.4ms
# Speed: 0.9ms preprocess, 43.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 66.0ms
# Speed: 1.1ms preprocess, 66.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 23 cars, 3 trucks, 49.5ms
# Speed: 1.0ms preprocess, 49.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 50.7ms
# Speed: 0.9ms preprocess, 50.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 24 cars, 1 bus, 3 trucks, 55.3ms
# Speed: 1.0ms preprocess, 55.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 31.4ms
# Speed: 0.9ms preprocess, 31.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 24 cars, 1 bus, 3 trucks, 36.5ms
# Speed: 0.8ms preprocess, 36.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 50.9ms
# Speed: 1.1ms preprocess, 50.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 23 cars, 3 trucks, 68.9ms
# Speed: 1.1ms preprocess, 68.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 51.9ms
# Speed: 1.0ms preprocess, 51.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 23 cars, 3 trucks, 48.6ms
# Speed: 1.0ms preprocess, 48.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 30.9ms
# Speed: 0.9ms preprocess, 30.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 25 cars, 1 bus, 3 trucks, 50.5ms
# Speed: 1.1ms preprocess, 50.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 31.3ms
# Speed: 0.9ms preprocess, 31.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 22 cars, 1 bus, 3 trucks, 48.9ms
# Speed: 0.9ms preprocess, 48.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 48.7ms
# Speed: 0.9ms preprocess, 48.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 23 cars, 1 bus, 4 trucks, 39.3ms
# Speed: 0.9ms preprocess, 39.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 34.0ms
# Speed: 0.9ms preprocess, 34.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 22 cars, 1 bus, 4 trucks, 53.2ms
# Speed: 1.2ms preprocess, 53.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 47.5ms
# Speed: 0.9ms preprocess, 47.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 20 cars, 1 bus, 4 trucks, 33.1ms
# Speed: 0.8ms preprocess, 33.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 48.3ms
# Speed: 1.3ms preprocess, 48.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 20 cars, 1 bus, 3 trucks, 50.4ms
# Speed: 1.0ms preprocess, 50.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 48.9ms
# Speed: 0.9ms preprocess, 48.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 21 cars, 1 bus, 4 trucks, 61.2ms
# Speed: 1.0ms preprocess, 61.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 29.6ms
# Speed: 0.9ms preprocess, 29.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 22 cars, 3 trucks, 50.5ms
# Speed: 1.2ms preprocess, 50.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 41.5ms
# Speed: 0.9ms preprocess, 41.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 21 cars, 3 trucks, 37.8ms
# Speed: 1.1ms preprocess, 37.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 32.4ms
# Speed: 0.8ms preprocess, 32.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 21 cars, 3 trucks, 76.3ms
# Speed: 1.0ms preprocess, 76.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 license_plates, 46.6ms
# Speed: 1.2ms preprocess, 46.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 21 cars, 3 trucks, 46.9ms
# Speed: 1.1ms preprocess, 46.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 33.5ms
# Speed: 0.9ms preprocess, 33.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 20 cars, 3 trucks, 48.4ms
# Speed: 1.0ms preprocess, 48.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 license_plates, 42.7ms
# Speed: 1.1ms preprocess, 42.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 21 cars, 3 trucks, 72.0ms
# Speed: 0.7ms preprocess, 72.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 40.5ms
# Speed: 1.0ms preprocess, 40.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 23 cars, 3 trucks, 36.2ms
# Speed: 1.0ms preprocess, 36.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 32.9ms
# Speed: 0.7ms preprocess, 32.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 21 cars, 3 trucks, 58.9ms
# Speed: 1.0ms preprocess, 58.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 51.3ms
# Speed: 1.0ms preprocess, 51.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 22 cars, 3 trucks, 34.2ms
# Speed: 1.0ms preprocess, 34.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 49.8ms
# Speed: 1.0ms preprocess, 49.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 21 cars, 3 trucks, 73.7ms
# Speed: 1.0ms preprocess, 73.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 53.1ms
# Speed: 1.1ms preprocess, 53.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 19 cars, 3 trucks, 34.3ms
# Speed: 1.1ms preprocess, 34.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 34.2ms
# Speed: 0.9ms preprocess, 34.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 23 cars, 3 trucks, 35.8ms
# Speed: 0.8ms preprocess, 35.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 31.6ms
# Speed: 0.9ms preprocess, 31.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 21 cars, 3 trucks, 39.6ms
# Speed: 1.1ms preprocess, 39.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 52.8ms
# Speed: 1.1ms preprocess, 52.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 21 cars, 3 trucks, 55.0ms
# Speed: 1.1ms preprocess, 55.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 48.8ms
# Speed: 1.0ms preprocess, 48.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 22 cars, 3 trucks, 54.8ms
# Speed: 0.9ms preprocess, 54.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 45.0ms
# Speed: 1.1ms preprocess, 45.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 22 cars, 3 trucks, 48.0ms
# Speed: 0.8ms preprocess, 48.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 45.0ms
# Speed: 0.9ms preprocess, 45.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 23 cars, 3 trucks, 49.5ms
# Speed: 0.9ms preprocess, 49.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 58.0ms
# Speed: 0.9ms preprocess, 58.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 22 cars, 1 bus, 3 trucks, 54.2ms
# Speed: 1.0ms preprocess, 54.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 44.8ms
# Speed: 0.8ms preprocess, 44.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 21 cars, 1 bus, 3 trucks, 38.1ms
# Speed: 1.0ms preprocess, 38.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 33.2ms
# Speed: 1.1ms preprocess, 33.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 20 cars, 1 bus, 3 trucks, 56.9ms
# Speed: 1.1ms preprocess, 56.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 39.1ms
# Speed: 1.1ms preprocess, 39.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 22 cars, 1 bus, 3 trucks, 67.0ms
# Speed: 1.0ms preprocess, 67.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 45.8ms
# Speed: 1.2ms preprocess, 45.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 19 cars, 1 bus, 3 trucks, 49.7ms
# Speed: 1.0ms preprocess, 49.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 31.1ms
# Speed: 0.9ms preprocess, 31.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 20 cars, 1 bus, 3 trucks, 51.9ms
# Speed: 0.9ms preprocess, 51.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 46.9ms
# Speed: 0.9ms preprocess, 46.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 19 cars, 1 bus, 3 trucks, 77.9ms
# Speed: 1.0ms preprocess, 77.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 47.1ms
# Speed: 1.0ms preprocess, 47.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 22 cars, 1 bus, 3 trucks, 53.1ms
# Speed: 1.0ms preprocess, 53.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 53.1ms
# Speed: 1.0ms preprocess, 53.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 20 cars, 1 bus, 3 trucks, 49.5ms
# Speed: 1.1ms preprocess, 49.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 46.5ms
# Speed: 0.9ms preprocess, 46.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 21 cars, 1 bus, 3 trucks, 79.6ms
# Speed: 4.6ms preprocess, 79.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 49.3ms
# Speed: 0.9ms preprocess, 49.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 22 cars, 1 bus, 3 trucks, 51.7ms
# Speed: 1.0ms preprocess, 51.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 48.8ms
# Speed: 0.9ms preprocess, 48.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 22 cars, 1 bus, 3 trucks, 52.3ms
# Speed: 1.0ms preprocess, 52.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 41.5ms
# Speed: 1.0ms preprocess, 41.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 27 cars, 1 bus, 3 trucks, 49.9ms
# Speed: 0.9ms preprocess, 49.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 67.8ms
# Speed: 0.9ms preprocess, 67.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 24 cars, 1 bus, 3 trucks, 67.0ms
# Speed: 1.0ms preprocess, 67.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 46.1ms
# Speed: 0.9ms preprocess, 46.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 24 cars, 1 bus, 3 trucks, 34.6ms
# Speed: 0.9ms preprocess, 34.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 35.5ms
# Speed: 0.7ms preprocess, 35.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 24 cars, 1 bus, 3 trucks, 51.5ms
# Speed: 1.0ms preprocess, 51.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 license_plate, 48.7ms
# Speed: 1.0ms preprocess, 48.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)

# %%
# write results
write_csv(results, './test1.csv')

# %%
import csv
import numpy as np
from scipy.interpolate import interp1d

# %%
def interpolate_bounding_boxes(data):
    # Extract necessary data columns from input data
    frame_numbers = np.array([int(row['frame_nmr']) for row in data])
    car_ids = np.array([int(float(row['car_id'])) for row in data])
    car_bboxes = np.array([list(map(float, row['car_bbox'][1:-1].split())) for row in data])
    license_plate_bboxes = np.array([list(map(float, row['license_plate_bbox'][1:-1].split())) for row in data])

    interpolated_data = []
    unique_car_ids = np.unique(car_ids)
    for car_id in unique_car_ids:

        frame_numbers_ = [p['frame_nmr'] for p in data if int(float(p['car_id'])) == int(float(car_id))]
        print(frame_numbers_, car_id)

        # Filter data for a specific car ID
        car_mask = car_ids == car_id
        car_frame_numbers = frame_numbers[car_mask]
        car_bboxes_interpolated = []
        license_plate_bboxes_interpolated = []

        first_frame_number = car_frame_numbers[0]
        last_frame_number = car_frame_numbers[-1]

        for i in range(len(car_bboxes[car_mask])):
            frame_number = car_frame_numbers[i]
            car_bbox = car_bboxes[car_mask][i]
            license_plate_bbox = license_plate_bboxes[car_mask][i]

            if i > 0:
                prev_frame_number = car_frame_numbers[i-1]
                prev_car_bbox = car_bboxes_interpolated[-1]
                prev_license_plate_bbox = license_plate_bboxes_interpolated[-1]

                if frame_number - prev_frame_number > 1:
                    # Interpolate missing frames' bounding boxes
                    frames_gap = frame_number - prev_frame_number
                    x = np.array([prev_frame_number, frame_number])
                    x_new = np.linspace(prev_frame_number, frame_number, num=frames_gap, endpoint=False)
                    interp_func = interp1d(x, np.vstack((prev_car_bbox, car_bbox)), axis=0, kind='linear')
                    interpolated_car_bboxes = interp_func(x_new)
                    interp_func = interp1d(x, np.vstack((prev_license_plate_bbox, license_plate_bbox)), axis=0, kind='linear')
                    interpolated_license_plate_bboxes = interp_func(x_new)

                    car_bboxes_interpolated.extend(interpolated_car_bboxes[1:])
                    license_plate_bboxes_interpolated.extend(interpolated_license_plate_bboxes[1:])

            car_bboxes_interpolated.append(car_bbox)
            license_plate_bboxes_interpolated.append(license_plate_bbox)

        for i in range(len(car_bboxes_interpolated)):
            frame_number = first_frame_number + i
            row = {}
            row['frame_nmr'] = str(frame_number)
            row['car_id'] = str(car_id)
            row['car_bbox'] = ' '.join(map(str, car_bboxes_interpolated[i]))
            row['license_plate_bbox'] = ' '.join(map(str, license_plate_bboxes_interpolated[i]))

            if str(frame_number) not in frame_numbers_:
                # Imputed row, set the following fields to '0'
                row['license_plate_bbox_score'] = '0'
                row['license_number'] = '0'
                row['license_number_score'] = '0'
            else:
                # Original row, retrieve values from the input data if available
                original_row = [p for p in data if int(p['frame_nmr']) == frame_number and int(float(p['car_id'])) == int(float(car_id))][0]
                row['license_plate_bbox_score'] = original_row['license_plate_bbox_score'] if 'license_plate_bbox_score' in original_row else '0'
                row['license_number'] = original_row['license_number'] if 'license_number' in original_row else '0'
                row['license_number_score'] = original_row['license_number_score'] if 'license_number_score' in original_row else '0'

            interpolated_data.append(row)

    return interpolated_data

# %%
# Load the CSV file
with open('test.csv', 'r') as file:
    reader = csv.DictReader(file)
    data = list(reader)

# Interpolate missing data
interpolated_data = interpolate_bounding_boxes(data)

# Write updated data to a new CSV file
header = ['frame_nmr', 'car_id', 'car_bbox', 'license_plate_bbox', 'license_plate_bbox_score', 'license_number', 'license_number_score']
with open('test_interpolated.csv', 'w', newline='') as file:
    writer = csv.DictWriter(file, fieldnames=header)
    writer.writeheader()
    writer.writerows(interpolated_data)

# %%
import ast

import cv2
import numpy as np
import pandas as pd

# %%
def draw_border(img, top_left, bottom_right, color=(0, 255, 0), thickness=10, line_length_x=200, line_length_y=200):
    x1, y1 = top_left
    x2, y2 = bottom_right

    cv2.line(img, (x1, y1), (x1, y1 + line_length_y), color, thickness)  #-- top-left
    cv2.line(img, (x1, y1), (x1 + line_length_x, y1), color, thickness)

    cv2.line(img, (x1, y2), (x1, y2 - line_length_y), color, thickness)  #-- bottom-left
    cv2.line(img, (x1, y2), (x1 + line_length_x, y2), color, thickness)

    cv2.line(img, (x2, y1), (x2 - line_length_x, y1), color, thickness)  #-- top-right
    cv2.line(img, (x2, y1), (x2, y1 + line_length_y), color, thickness)

    cv2.line(img, (x2, y2), (x2, y2 - line_length_y), color, thickness)  #-- bottom-right
    cv2.line(img, (x2, y2), (x2 - line_length_x, y2), color, thickness)

    return img

# %%
results = pd.read_csv('./test_interpolated.csv')

# load video
video_path = '/home/mcw/Desktop/work/anpr/sample.mp4'
cap = cv2.VideoCapture(video_path)

fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Specify the codec
fps = cap.get(cv2.CAP_PROP_FPS)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
out = cv2.VideoWriter('../drive/MyDrive/Plateout.mp4', fourcc, fps, (width, height))

license_plate = {}
for car_id in np.unique(results['car_id']):
    max_ = np.amax(results[results['car_id'] == car_id]['license_number_score'])
    license_plate[car_id] = {'license_crop': None,
                             'license_plate_number': results[(results['car_id'] == car_id) &
                                                             (results['license_number_score'] == max_)]['license_number'].iloc[0]}
    cap.set(cv2.CAP_PROP_POS_FRAMES, results[(results['car_id'] == car_id) &
                                             (results['license_number_score'] == max_)]['frame_nmr'].iloc[0])
    ret, frame = cap.read()

    x1, y1, x2, y2 = ast.literal_eval(results[(results['car_id'] == car_id) &
                                              (results['license_number_score'] == max_)]['license_plate_bbox'].iloc[0].replace('[ ', '[').replace('   ', ' ').replace('  ', ' ').replace(' ', ','))

    license_crop = frame[int(y1):int(y2), int(x1):int(x2), :]
    license_crop = cv2.resize(license_crop, (int((x2 - x1) * 400 / (y2 - y1)), 400))

    license_plate[car_id]['license_crop'] = license_crop

# %%
frame_nmr = -1

cap.set(cv2.CAP_PROP_POS_FRAMES, 0)

# read frames
ret = True
while ret:
    ret, frame = cap.read()
    frame_nmr += 1
    if ret:
        df_ = results[results['frame_nmr'] == frame_nmr]
        for row_indx in range(len(df_)):
            # draw car
            car_x1, car_y1, car_x2, car_y2 = ast.literal_eval(df_.iloc[row_indx]['car_bbox'].replace('[ ', '[').replace('   ', ' ').replace('  ', ' ').replace(' ', ','))
            draw_border(frame, (int(car_x1), int(car_y1)), (int(car_x2), int(car_y2)), (0, 255, 0), 25,
                        line_length_x=200, line_length_y=200)

            # draw license plate
            x1, y1, x2, y2 = ast.literal_eval(df_.iloc[row_indx]['license_plate_bbox'].replace('[ ', '[').replace('   ', ' ').replace('  ', ' ').replace(' ', ','))
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 0, 255), 12)

            # crop license plate
            license_crop = license_plate[df_.iloc[row_indx]['car_id']]['license_crop']

            H, W, _ = license_crop.shape

            try:
                frame[int(car_y1) - H - 100:int(car_y1) - 100,
                      int((car_x2 + car_x1 - W) / 2):int((car_x2 + car_x1 + W) / 2), :] = license_crop

                frame[int(car_y1) - H - 400:int(car_y1) - H - 100,
                      int((car_x2 + car_x1 - W) / 2):int((car_x2 + car_x1 + W) / 2), :] = (255, 255, 255)

                (text_width, text_height), _ = cv2.getTextSize(
                    license_plate[df_.iloc[row_indx]['car_id']]['license_plate_number'],
                    cv2.FONT_HERSHEY_SIMPLEX,
                    4.3,
                    17)

                cv2.putText(frame,
                            license_plate[df_.iloc[row_indx]['car_id']]['license_plate_number'],
                            (int((car_x2 + car_x1 - text_width) / 2), int(car_y1 - H - 250 + (text_height / 2))),
                            cv2.FONT_HERSHEY_SIMPLEX,
                            4.3,
                            (0, 0, 0),
                            17)

            except:
                pass

        out.write(frame)
        frame = cv2.resize(frame, (1280, 720))

        # cv2.imshow('frame', frame)
        # cv2.waitKey(0)

out.release()
cap.release()
